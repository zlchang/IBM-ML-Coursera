# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo">
#     </a>
# </p>

# %% [markdown]
# # **Web Scraping Lab**

# %% [markdown]
# Estimated time needed: **30** minutes

# %% [markdown]
# ## Objectives

# %% [markdown]
# After completing this lab you will be:
#
# * Familiar with the basics of the `BeautifulSoup` Python library
# * Be able to scrape webpages for data and filter the data

# %% [markdown]
# <h2>Table of Contents</h2>
# <div class="alert alert-block alert-info" style="margin-top: 20px">
#     <ul>
#         <li>
#             <a href="BSO">Beautiful Soup Object</a>
#             <ul>
#                 <li>Tag</li>
#                 <li>Children, Parents, and Siblings</li>
#                 <li>HTML Attributes</li>
#                 <li>Navigable String</li>
#             </ul>
#         </li>
#      </ul>
#     <ul>
#         <li>
#             <a href="filter">Filter</a>
#             <ul>
#                 <li>find All</li>
#                 <li>find </li>
#                 <li>HTML Attributes</li>
#                 <li>Navigable String</li>
#             </ul>
#         </li>
#      </ul>
#      <ul>
#         <li>
#             <a href="DSCW">Downloading And Scraping The Contents Of A Web</a>
#     </p>
#
# </div>
#
# <hr>

# %% [markdown]
# For this lab, we are going to be using Python and several Python libraries. Some of these libraries might be installed in your lab environment or in SN Labs. Others may need to be installed by you. The cells below will install these libraries when executed.

# %%
# !pip install bs4
# !pip install requests pandas
# Out:
# Collecting bs4
#   Downloading bs4-0.0.2-py2.py3-none-any.whl.metadata (411 bytes)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.12/site-packages (from bs4) (4.12.3)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.12/site-packages (from beautifulsoup4->bs4) (2.5)
# Downloading bs4-0.0.2-py2.py3-none-any.whl (1.2 kB)
# Installing collected packages: bs4
# Successfully installed bs4-0.0.2
# Requirement already satisfied: requests in /opt/conda/lib/python3.12/site-packages (2.32.3)
# Collecting pandas
#   Downloading pandas-3.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl.metadata (79 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /opt/conda/lib/python3.12/site-packages (from requests) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.12/site-packages (from requests) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.12/site-packages (from requests) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.12/site-packages (from requests) (2024.12.14)
# Collecting numpy>=1.26.0 (from pandas)
#   Downloading numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl.metadata (6.6 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/conda/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading pandas-3.0.1-cp312-cp312-manylinux_2_24_x86_64.manylinux_2_28_x86_64.whl (10.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.9/10.9 MB 184.1 MB/s eta 0:00:00
# Downloading numpy-2.4.4-cp312-cp312-manylinux_2_27_x86_64.manylinux_2_28_x86_64.whl (16.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.6/16.6 MB 194.4 MB/s eta 0:00:00
# Installing collected packages: numpy, pandas
# Successfully installed numpy-2.4.4 pandas-3.0.1

# %% [markdown]
# Import the required modules and functions

# %%
from bs4 import BeautifulSoup # this module helps in web scrapping.
import requests  # this module helps us to download a web page

# %% [markdown]
# <h2 id="BSO">Beautiful Soup Objects</h2>

# %% [markdown]
# Beautiful Soup is a Python library for pulling data out of HTML and XML files, we will focus on HTML files. This is accomplished by representing the HTML as a set of objects with methods used to parse the HTML.  We can navigate the HTML as a tree, and/or filter out what we are looking for.
#
# Consider the following HTML:

# %%
# %%html
# <!DOCTYPE html>
# <html>
# <head>
# <title>Page Title</title>
# </head>
# <body>
# <h3><b id='boldest'>Lebron James</b></h3>
# <p> Salary: $ 92,000,000 </p>
# <h3> Stephen Curry</h3>
# <p> Salary: $85,000, 000 </p>
# <h3> Kevin Durant </h3>
# <p> Salary: $73,200, 000</p>
# </body>
# </html>
# Out:
# <!DOCTYPE html>
# <html>
# <head>
# <title>Page Title</title>
# </head>
# <body>
# <h3><b id='boldest'>Lebron James</b></h3>
# <p> Salary: $ 92,000,000 </p>
# <h3> Stephen Curry</h3>
# <p> Salary: $85,000, 000 </p>
# <h3> Kevin Durant </h3>
# <p> Salary: $73,200, 000</p>
# </body>
# </html>

# %% [markdown]
# We can store it as a string in the variable HTML:

# %%
html="<!DOCTYPE html><html><head><title>Page Title</title></head><body><h3><b id='boldest'>Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body></html>"

# %% [markdown]
# To parse a document, pass it into the <code>BeautifulSoup</code> constructor. The <code>BeautifulSoup</code> object represents the document as a nested data structure:

# %%
soup = BeautifulSoup(html, 'html.parser')

# %% [markdown]
# First, the document is converted to Unicode (similar to ASCII) and HTML entities are converted to Unicode characters. Beautiful Soup transforms a complex HTML document into a complex tree of Python objects. The <code>BeautifulSoup</code> object can create other types of objects. In this lab, we will cover <code>BeautifulSoup</code> and <code>Tag</code> objects, that for the purposes of this lab are identical. Finally, we will look at <code>NavigableString</code> objects.

# %% [markdown]
# We can use the method <code>prettify()</code> to display the HTML in the nested structure:

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html>
#  <head>
#   <title>
#    Page Title
#   </title>
#  </head>
#  <body>
#   <h3>
#    <b id="boldest">
#     Lebron James
#    </b>
#   </h3>
#   <p>
#    Salary: $ 92,000,000
#   </p>
#   <h3>
#    Stephen Curry
#   </h3>
#   <p>
#    Salary: $85,000, 000
#   </p>
#   <h3>
#    Kevin Durant
#   </h3>
#   <p>
#    Salary: $73,200, 000
#   </p>
#  </body>
# </html>

# %% [markdown]
# ## Tags

# %% [markdown]
# Let's say we want the  title of the page and the name of the top paid player. We can use the <code>Tag</code>. The <code>Tag</code> object corresponds to an HTML tag in the original document, for example, the tag title.

# %%
tag_object=soup.title
print("tag object:",tag_object)
# Out:
# tag object: <title>Page Title</title>

# %% [markdown]
# we can see the tag type <code>bs4.element.Tag</code>

# %%
print("tag object type:",type(tag_object), type(html))
# Out:
# tag object type: <class 'bs4.element.Tag'> <class 'str'>

# %% [markdown]
# If there is more than one <code>Tag</code> with the same name, the first element with that <code>Tag</code> name is called. This corresponds to the most paid player:

# %%
tag_object=soup.h3
tag_object
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %%
tag_object.text.strip()
# Out:
# 'Lebron James'

# %% [markdown]
# Enclosed in the bold attribute <code>b</code>, it helps to use the tree representation. We can navigate down the tree using the child attribute to get the name.

# %% [markdown]
# ### Children, Parents, and Siblings

# %% [markdown]
# As stated above, the <code>Tag</code> object is a tree of objects. We can access the child of the tag or navigate down the branch as follows:

# %%
tag_child =tag_object.b
tag_child
# Out:
# <b id="boldest">Lebron James</b>

# %% [markdown]
# You can access the parent with the <code> parent</code>

# %%
parent_tag=tag_child.parent
parent_tag
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %% [markdown]
# this is identical to:

# %%
tag_object
# Out:
# <h3><b id="boldest">Lebron James</b></h3>

# %%
tag_child.text.strip()
# Out:
# 'Lebron James'

# %% [markdown]
# <code>tag_object</code> parent is the <code>body</code> element.

# %%
tag_object.parent
# Out:
# <body><h3><b id="boldest">Lebron James</b></h3><p> Salary: $ 92,000,000 </p><h3> Stephen Curry</h3><p> Salary: $85,000, 000 </p><h3> Kevin Durant </h3><p> Salary: $73,200, 000</p></body>

# %% [markdown]
# <code>tag_object</code> sibling is the <code>paragraph</code> element

# %%
sibling_1=tag_object.next_sibling
sibling_1
# Out:
# <p> Salary: $ 92,000,000 </p>

# %% [markdown]
# `sibling_2` is the `header` element, which is also a sibling of both `sibling_1` and `tag_object`

# %%
sibling_2=sibling_1.next_sibling
sibling_2
# Out:
# <h3> Stephen Curry</h3>

# %% [markdown]
# <h3 id="first_question">Exercise: <code>next_sibling</code></h3>

# %% [markdown]
# Use the object <code>sibling_2</code> and the method <code>next_sibling</code> to find the salary of Stephen Curry:

# %%
sibling_3 = sibling_2.next_sibling
sibling_3
# Out:
# <p> Salary: $85,000, 000 </p>

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```
# sibling_2.next_sibling
#
# ```
#
# </details>

# %% [markdown]
# ### HTML Attributes

# %% [markdown]
# If the tag has attributes, the tag <code>id="boldest"</code> has an attribute <code>id</code> whose value is <code>boldest</code>. You can access a tag’s attributes by treating the tag like a dictionary:

# %%
tag_child['id']
# Out:
# 'boldest'

# %%
type(tag_child)
# Out:
# bs4.element.Tag

# %% [markdown]
# You can access that dictionary directly as <code>attrs</code>:

# %%
tag_child.attrs
# Out:
# {'id': 'boldest'}

# %% [markdown]
# You can also work with Multi-valued attributes. Check out <a href="https://www.crummy.com/software/BeautifulSoup/bs4/doc/">[1]</a> for more.

# %% [markdown]
# We can also obtain the content of the attribute of the <code>tag</code> using the Python <code>get()</code> method.

# %%
tag_child.get('id')
# Out:
# 'boldest'

# %% [markdown]
# ### Navigable String

# %% [markdown]
# A string corresponds to a bit of text or content within a tag. Beautiful Soup uses the <code>NavigableString</code> class to contain this text. In our HTML we can obtain the name of the first player by extracting the string of the <code>Tag</code> object <code>tag_child</code> as follows:

# %%
tag_string=tag_child.string
tag_string
# Out:
# 'Lebron James'

# %% [markdown]
# we can verify the type is Navigable String

# %%
type(tag_string)
# Out:
# bs4.element.NavigableString

# %% [markdown]
# A NavigableString is similar to a Python string or Unicode string. To be more precise, the main difference is that it also supports some <code>BeautifulSoup</code> features. We can convert it to string object in Python:

# %%
unicode_string = str(tag_string)
unicode_string
# Out:
# 'Lebron James'

# %% [markdown]
# <h2 id="filter">Filter</h2>

# %% [markdown]
# Filters allow you to find complex patterns, the simplest filter is a string. In this section we will pass a string to a different filter method and Beautiful Soup will perform a match against that exact string. Consider the following HTML of rocket launches:

# %%
# %%html
# <table>
#   <tr>
#     <td id='flight' >Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#    </tr>
#   <tr>
#     <td>1</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida</a></td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a> </td>
#     <td>80 kg</td>
#   </tr>
# </table>
# Out:
# <table>
#   <tr>
#     <td id='flight' >Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#    </tr>
#   <tr>
#     <td>1</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida</a></td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a> </td>
#     <td>80 kg</td>
#   </tr>
# </table>

# %% [markdown]
# We can store it as a string in the variable <code>table</code>:

# %%
table="<table><tr><td id='flight'>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr> <td>1</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a></td><td>300 kg</td></tr><tr><td>2</td><td><a href='https://en.wikipedia.org/wiki/Texas'>Texas</a></td><td>94 kg</td></tr><tr><td>3</td><td><a href='https://en.wikipedia.org/wiki/Florida'>Florida<a> </td><td>80 kg</td></tr></table>"

# %%
table_bs = BeautifulSoup(table, 'html.parser')

# %% [markdown]
# ## find All

# %% [markdown]
# The <code>find_all()</code> method looks through a tag’s descendants and retrieves all descendants that match your filters.
#
# <p>
# The Method signature for <code>find_all(name, attrs, recursive, string, limit, **kwargs)<c/ode>
# </p>

# %% [markdown]
# ### Name

# %% [markdown]
# When we set the <code>name</code> parameter to a tag name, the method will extract all the tags with that name and its children.

# %%
table_rows=table_bs.find_all('tr')
table_rows
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>,
#  <tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td><td>300 kg</td></tr>,
#  <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>,
#  <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td><td>80 kg</td></tr>]

# %% [markdown]
# The result is a Python Iterable just like a list, each element is a <code>tag</code> object:

# %%
first_row =table_rows[0]
first_row
# Out:
# <tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>

# %% [markdown]
# The type is <code>tag</code>

# %%
print(type(first_row))
# Out:
# <class 'bs4.element.Tag'>

# %% [markdown]
# we can obtain the child

# %%
first_row.td
# Out:
# <td id="flight">Flight No</td>

# %%
print(type(first_row.td))
# Out:
# <class 'bs4.element.Tag'>

# %% [markdown]
# If we iterate through the list, each element corresponds to a row in the table:

# %%
for i,row in enumerate(table_rows):
    print("row",i,"is",row)
# Out:
# row 0 is <tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>
# row 1 is <tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td><td>300 kg</td></tr>
# row 2 is <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>
# row 3 is <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td><td>80 kg</td></tr>

# %% [markdown]
# As <code>row</code> is a <code>cell</code> object, we can apply the method <code>find_all</code> to it and extract table cells in the object <code>cells</code> using the tag <code>td</code>, this is all the children with the name <code>td</code>. The result is a list, each element corresponds to a cell and is a <code>Tag</code> object, we can iterate through this list as well. We can extract the content using the <code>string</code> attribute.

# %%
for i,row in enumerate(table_rows):
    print("row",i)
    cells=row.find_all('td')
    for j,cell in enumerate(cells):
        print('colunm',j,"cell",cell)
# Out:
# row 0
# colunm 0 cell <td id="flight">Flight No</td>
# colunm 1 cell <td>Launch site</td>
# colunm 2 cell <td>Payload mass</td>
# row 1
# colunm 0 cell <td>1</td>
# colunm 1 cell <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td>
# colunm 2 cell <td>300 kg</td>
# row 2
# colunm 0 cell <td>2</td>
# colunm 1 cell <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>
# colunm 2 cell <td>94 kg</td>
# row 3
# colunm 0 cell <td>3</td>
# colunm 1 cell <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td>
# colunm 2 cell <td>80 kg</td>

# %% [markdown]
# If we use a list we can match against any item in that list.

# %%
list_input=table_bs .find_all(name=["tr", "td"])
list_input
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>,
#  <td id="flight">Flight No</td>,
#  <td>Launch site</td>,
#  <td>Payload mass</td>,
#  <tr> <td>1</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td><td>300 kg</td></tr>,
#  <td>1</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a></td>,
#  <td>300 kg</td>,
#  <tr><td>2</td><td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td><td>94 kg</td></tr>,
#  <td>2</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Texas">Texas</a></td>,
#  <td>94 kg</td>,
#  <tr><td>3</td><td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td><td>80 kg</td></tr>,
#  <td>3</td>,
#  <td><a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a></td>,
#  <td>80 kg</td>]

# %% [markdown]
# ## Attributes

# %% [markdown]
# If the argument is not recognized it will be turned into a filter on the tag’s attributes. For example with the <code>id</code> argument, Beautiful Soup will filter against each tag’s <code>id</code> attribute. For example, the first <code>td</code> elements have a value of <code>id</code> of <code>flight</code>, therefore we can filter based on that <code>id</code> value.

# %%
table_bs.find_all(id="flight")
# Out:
# [<td id="flight">Flight No</td>]

# %% [markdown]
# We can find all the elements that have links to the Florida Wikipedia page:

# %%
list_input=table_bs.find_all(href="https://en.wikipedia.org/wiki/Florida")
list_input
# Out:
# [<a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a>,
#  <a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a>]

# %% [markdown]
# If we set the <code>href</code> attribute to True, regardless of what the value is, the code finds all tags with <code>href</code> value:

# %%
table_bs.find_all(href=True)
# Out:
# [<a href="https://en.wikipedia.org/wiki/Florida">Florida<a></a></a>,
#  <a href="https://en.wikipedia.org/wiki/Texas">Texas</a>,
#  <a href="https://en.wikipedia.org/wiki/Florida">Florida<a> </a></a>]

# %% [markdown]
# There are other methods for dealing with attributes and other related methods. Check out the following <a href='https://www.crummy.com/software/BeautifulSoup/bs4/doc/#css-selectors'>link</a>

# %% [markdown]
# <h3 id="exer_type">Exercise: <code>find_all</code></h3>

# %% [markdown]
# Find all the `<a>` tags without <code>href</code> value

# %%
table_bs.find_all(lambda tag: tag.name == 'a' and not tag.has_attr("href"))
# Out:
# [<a></a>, <a> </a>]

# %%
table_bs.find_all(lambda tag: not tag.has_attr("href") and not tag.find('a'))
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>,
#  <td id="flight">Flight No</td>,
#  <td>Launch site</td>,
#  <td>Payload mass</td>,
#  <td>1</td>,
#  <a></a>,
#  <td>300 kg</td>,
#  <td>2</td>,
#  <td>94 kg</td>,
#  <td>3</td>,
#  <a> </a>,
#  <td>80 kg</td>]

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```
# table_bs.find_all(lambda tag: tag.name == "a" and not tag.has_attr("href"))
#
# ```
#
# </details>

# %% [markdown]
# Find all the elements that do not contain any links

# %%
table_bs.find_all(lambda tag: tag.name != "a" and not tag.find('a'))
# Out:
# [<tr><td id="flight">Flight No</td><td>Launch site</td> <td>Payload mass</td></tr>,
#  <td id="flight">Flight No</td>,
#  <td>Launch site</td>,
#  <td>Payload mass</td>,
#  <td>1</td>,
#  <td>300 kg</td>,
#  <td>2</td>,
#  <td>94 kg</td>,
#  <td>3</td>,
#  <td>80 kg</td>]

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```
# table_bs.find_all(lambda tag: tag.name != "a" and not tag.find('a'))
#
# ```
#
# </details>

# %% [markdown]
# Using the soup object <code>soup</code>, find the element with the <code>id</code> attribute content set to <code>"boldest"</code>.

# %%
table_bs.find_all(id='boldest')
# Out:
# []

# %%
tag_id = soup.find_all(lambda tag: tag.has_attr("id") and tag["id"] == "boldest")
print(type(tag_id))
if len(tag_id):
    print(tag_id[0].get("id"))
# Out:
# <class 'bs4.element.ResultSet'>

# %% [markdown]
# <details><summary>Click here for the solution</summary>
#
# ```
# soup.find_all(id="boldest")
#
# ```
#
# </details>

# %% [markdown]
# ### string

# %% [markdown]
# With string you can search for strings instead of tags, where we find all the elments with Florida:

# %%
table_bs.find_all(string="Florida")
# Out:
# ['Florida', 'Florida']

# %% [markdown]
# ## find

# %% [markdown]
# The <code>find_all()</code> method scans the entire document looking for results. It’s useful if you are looking for one element, as you can use the <code>find()</code> method to find the first element in the document. Consider the following two tables:

# %%
# %%html
# <h3>Rocket Launch </h3>
#
# <p>
# <table class='rocket'>
#   <tr>
#     <td>Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Florida</td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>Texas</td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>Florida </td>
#     <td>80 kg</td>
#   </tr>
# </table>
# </p>
# <p>
#
# <h3>Pizza Party  </h3>
#
#
# <table class='pizza'>
#   <tr>
#     <td>Pizza Place</td>
#     <td>Orders</td>
#     <td>Slices </td>
#    </tr>
#   <tr>
#     <td>Domino's Pizza</td>
#     <td>10</td>
#     <td>100</td>
#   </tr>
#   <tr>
#     <td>Little Caesars</td>
#     <td>12</td>
#     <td >144 </td>
#   </tr>
#   <tr>
#     <td>Papa John's </td>
#     <td>15 </td>
#     <td>165</td>
#   </tr>
# Out:
# <h3>Rocket Launch </h3>
#
# <p>
# <table class='rocket'>
#   <tr>
#     <td>Flight No</td>
#     <td>Launch site</td>
#     <td>Payload mass</td>
#   </tr>
#   <tr>
#     <td>1</td>
#     <td>Florida</td>
#     <td>300 kg</td>
#   </tr>
#   <tr>
#     <td>2</td>
#     <td>Texas</td>
#     <td>94 kg</td>
#   </tr>
#   <tr>
#     <td>3</td>
#     <td>Florida </td>
#     <td>80 kg</td>
#   </tr>
# </table>
# </p>
# <p>
#
# <h3>Pizza Party  </h3>
#
#
# <table class='pizza'>
#   <tr>
#     <td>Pizza Place</td>
#     <td>Orders</td>
#     <td>Slices </td>
#    </tr>
#   <tr>
#     <td>Domino's Pizza</td>
#     <td>10</td>
#     <td>100</td>
#   </tr>
#   <tr>
#     <td>Little Caesars</td>
#     <td>12</td>
#     <td >144 </td>
#   </tr>
#   <tr>
#     <td>Papa John's </td>
#     <td>15 </td>
#     <td>165</td>
#   </tr>

# %% [markdown]
# We store the HTML as a Python string and assign <code>two_tables</code>:

# %%
two_tables="<h3>Rocket Launch </h3><p><table class='rocket'><tr><td>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr><td>1</td><td>Florida</td><td>300 kg</td></tr><tr><td>2</td><td>Texas</td><td>94 kg</td></tr><tr><td>3</td><td>Florida </td><td>80 kg</td></tr></table></p><p><h3>Pizza Party  </h3><table class='pizza'><tr><td>Pizza Place</td><td>Orders</td> <td>Slices </td></tr><tr><td>Domino's Pizza</td><td>10</td><td>100</td></tr><tr><td>Little Caesars</td><td>12</td><td >144 </td></tr><tr><td>Papa John's </td><td>15 </td><td>165</td></tr>"

# %% [markdown]
# We create a <code>BeautifulSoup</code> object  <code>two_tables_bs</code>

# %%
two_tables_bs= BeautifulSoup(two_tables, 'html.parser')

# %% [markdown]
# We can find the first table using the tag name table

# %%
two_tables_bs.find("table")
# Out:
# <table class="rocket"><tr><td>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr><td>1</td><td>Florida</td><td>300 kg</td></tr><tr><td>2</td><td>Texas</td><td>94 kg</td></tr><tr><td>3</td><td>Florida </td><td>80 kg</td></tr></table>

# %%
two_tables_bs.find_all("table")
# Out:
# [<table class="rocket"><tr><td>Flight No</td><td>Launch site</td> <td>Payload mass</td></tr><tr><td>1</td><td>Florida</td><td>300 kg</td></tr><tr><td>2</td><td>Texas</td><td>94 kg</td></tr><tr><td>3</td><td>Florida </td><td>80 kg</td></tr></table>,
#  <table class="pizza"><tr><td>Pizza Place</td><td>Orders</td> <td>Slices </td></tr><tr><td>Domino's Pizza</td><td>10</td><td>100</td></tr><tr><td>Little Caesars</td><td>12</td><td>144 </td></tr><tr><td>Papa John's </td><td>15 </td><td>165</td></tr></table>]

# %% [markdown]
# We can filter on the class attribute to find the second table, but because class is a keyword in Python, we add an underscore to differentiate them.

# %%
two_tables_bs.find("table",class_='pizza')
# Out:
# <table class="pizza"><tr><td>Pizza Place</td><td>Orders</td> <td>Slices </td></tr><tr><td>Domino's Pizza</td><td>10</td><td>100</td></tr><tr><td>Little Caesars</td><td>12</td><td>144 </td></tr><tr><td>Papa John's </td><td>15 </td><td>165</td></tr></table>

# %% [markdown]
# <h2 id="DSCW">Downloading And Scraping The Contents Of A Web Page</h2>

# %% [markdown]
# We Download the contents of the web page:

# %%
url = "http://www.ibm.com"

# %% [markdown]
# We use <code>get</code> to download the contents of the webpage in text format and store in a variable called <code>data</code>:

# %%
data  = requests.get(url).text

# %% [markdown]
# We create a <code>BeautifulSoup</code> object using the <code>BeautifulSoup</code> constructor

# %%
soup = BeautifulSoup(data,"html.parser")  # create a soup object using the variable 'data'

# %% [markdown]
# Scrape all links

# %%
for link in soup.find_all('a',href=True):  # in html anchor/link is represented by the tag <a>

    print(link.get('href'))
# Out:
# https://www.ibm.com/events/think?lnk=hpprus&utm_id=PBushp
# https://www.ibm.com/think/insights/strengthen-architecture-before-scaling-ai?lnk=hpls1us
# https://www.ibm.com/solutions/application-integration?lnk=hpls2us
# https://www.ibm.com/thought-leadership/institute-business-value/report/2026-banking-financial-markets-outlook?lnk=hprc1us
# https://www.ibm.com/think/insights/revenue-problem-no-one-sees-coming?lnk=hprc2us
# https://www.ibm.com/think/prompt-engineering?lnk=hprc3us
# https://www.ibm.com/quantum/blog/open-plan-updates?lnk=hprc4us
# https://www.ibm.com/case-studies/us-open?lnk=hpcs2us
# https://www.ibm.com/case-studies/pfizer?lnk=hpcs3us
# https://www.ibm.com/case-studies/ufc?lnk=hpcs1us
# https://www.ibm.com/case-studies/scuderia-ferrari?lnk=hpcs4us
# https://www.ibm.com/products/offers-and-discounts?lnk=hpdo1us
# https://www.ibm.com/software?lnk=hpfp1us
# https://www.ibm.com/software/ai-productivity?lnk=hpfp2us
# https://www.ibm.com/software/data-management?lnk=hpfp3us
# https://www.ibm.com/software/security-governance?lnk=hpfp4us
# https://www.ibm.com/software/integration-resilience?lnk=hpfp5us
# https://www.ibm.com/software/hybrid-infrastructure-management?lnk=hpfp6us
# https://www.ibm.com/solutions/ai-models?lnk=hpfp7us
# https://www.ibm.com/solutions/analytics?lnk=hpfp8us
# https://www.ibm.com/consulting?lnk=hpfp9us
# https://www.ibm.com/training?utm_source=hp&utm_campaign=ushp&utm_medium=organic&lnk=hptr3us
# https://www.ibm.com/training?utm_source=hp&utm_campaign=ushp&utm_medium=organic&lnk=hptr3us
# https://skillsbuild.org/adult-learners?lnk=hptr2us/?utm_source=ibm.com&utm_campaign=ibmus&utm_medium=organic
# https://skillsbuild.org/college-students?lnk=hptr1us/?utm_source=ibm.com&utm_campaign=ibmus&utm_medium=organic
# https://newsroom.ibm.com/2026-03-26-ibm-quantum-computer-accurately-simulates-real-magnetic-materials,-reproducing-national-laboratory-data
# https://newsroom.ibm.com/2026-03-25-enterprise-ai-finds-its-voice-elevenlabs-and-ibm-bring-premium-voice-capabilities-to-agentic-ai
# https://newsroom.ibm.com/2026-03-23-ibm-debuts-new-ai-enabled-digital-experiences-for-the-90th-masters-tournament
# https://newsroom.ibm.com/2026-03-18-ibm-fellow-and-quantum-pioneer-charles-h-bennett-receives-a-m-turing-award-computings-highest-honor
# https://newsroom.ibm.com/2026-03-17-ibm-completes-acquisition-of-confluent,-making-real-time-data-the-engine-of-enterprise-ai-and-agents
# https://newsroom.ibm.com/2026-03-16-ibm-and-nvidia-announce-expanded-collaboration-at-gtc-2026-to-advance-ai-for-the-enterprise
# https://newsroom.ibm.com/2026-03-12-ibm-releases-a-new-blueprint-for-quantum-centric-supercomputing
# https://newsroom.ibm.com/2026-03-10-ibm-and-lam-research-announce-collaboration-to-advance-sub-1nm-logic-scaling

# %% [markdown]
# ## Scrape  all images  Tags

# %%
for link in soup.find_all('img'):# in html image is represented by the tag <img>
    print(link)
    print(link.get('src'))
# Out:
# <img alt="3D glass shapes on line paths" class="cmp-image__image" height="768" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/1580-outlook-for-banking_768x768?ts=1774880785421&amp;dpr=off" srcset="..." title="Abstract geometric shapes in purple and blue tones" width="768"/>
# https://assets.ibm.com/is/image/ibm/1580-outlook-for-banking_768x768?ts=1774880785421&dpr=off
# <img alt="An abstract representation of integration" class="cmp-image__image" height="1000" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/hp-perso-integration-r4u3-1x1?ts=1774880786218&amp;dpr=off" srcset="..." title="Abstract blue geometric connection concept illustration" width="1000"/>
# https://assets.ibm.com/is/image/ibm/hp-perso-integration-r4u3-1x1?ts=1774880786218&dpr=off
# <img alt="An isometric illustration of an data path junction" class="cmp-image__image" height="1000" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/hp-perso-integration-r4u4-1x1?ts=1774880799094&amp;dpr=off" srcset="..." title="Abstract purple intersection with blue ribbon elements" width="1000"/>
# https://assets.ibm.com/is/image/ibm/hp-perso-integration-r4u4-1x1?ts=1774880799094&dpr=off
# <img alt="An abstract representation of squares and circular dial" class="cmp-image__image" height="1616" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/accelerate-integration-1x1?ts=1774880805530&amp;dpr=off" srcset="..." title="Abstract Blue Geometric Shapes on Grid Background" width="1616"/>
# https://assets.ibm.com/is/image/ibm/accelerate-integration-1x1?ts=1774880805530&dpr=off
# <img alt="US Open logo" class="cmp-image__image" height="501" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/us-open-logo-2-1-v2-no-margin?ts=1774880809080&amp;dpr=off" srcset="..." title="US Open Tennis Tournament Yellow Ball Logo" width="1002"/>
# https://assets.ibm.com/is/image/ibm/us-open-logo-2-1-v2-no-margin?ts=1774880809080&dpr=off
# <img alt="Pfizer logo" class="cmp-image__image" height="2591" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/pfizer_logo-1?ts=1774880811637&amp;dpr=off" srcset="..." width="6276"/>
# https://assets.ibm.com/is/image/ibm/pfizer_logo-1?ts=1774880811637&dpr=off
# <img alt="UFC logo" class="cmp-image__image" height="8907" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/16-9-logo-ufc?ts=1774880814295&amp;dpr=off" srcset="..." title="Bold UFC logo in red font" width="15834"/>
# https://assets.ibm.com/is/image/ibm/16-9-logo-ufc?ts=1774880814295&dpr=off
# <img alt="Ferrari logo" class="cmp-image__image" height="1920" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/ferrari-shield-transparent?ts=1774880816940&amp;dpr=off" srcset="..." title="Ferrari emblem with prancing horse design" width="3840"/>
# https://assets.ibm.com/is/image/ibm/ferrari-shield-transparent?ts=1774880816940&dpr=off
# <img alt="Arthur Ashe Stadium, at the US Open 2025" class="cmp-image__image" height="1667" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/ashe-day-1-dustin-satloff_usta-2500pxw?ts=1774880808699&amp;dpr=off" srcset="..." title="Crowded tennis stadium during live match" width="2500"/>
# https://assets.ibm.com/is/image/ibm/ashe-day-1-dustin-satloff_usta-2500pxw?ts=1774880808699&dpr=off
# <img alt="Pfizer + IBM logos over 3d render of blue molecules" class="cmp-image__image" height="2160" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/pfizer_thumb?ts=1774880811314&amp;dpr=off" srcset="..." title="Pfizer and IBM collaboration visual concept" width="3840"/>
# https://assets.ibm.com/is/image/ibm/pfizer_thumb?ts=1774880811314&dpr=off
# <img alt="A general view of the Octagon during the UFC 291 event at Delta Center on July 29, 2023 in Salt Lake City, Utah." class="cmp-image__image" height="2560" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/ufc-octagon-9?ts=1774880813996&amp;dpr=off" srcset="..." width="3840"/>
# https://assets.ibm.com/is/image/ibm/ufc-octagon-9?ts=1774880813996&dpr=off
# <img alt="F1 racer in Ferrari´s team with Ferrari and IBM logo" class="cmp-image__image" height="3840" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/f678_still_f06_v10_zyn_4096x4096?ts=1774880816610&amp;dpr=off" srcset="..." title="Rear view of Formula 1 race car with IBM logo" width="3840"/>
# https://assets.ibm.com/is/image/ibm/f678_still_f06_v10_zyn_4096x4096?ts=1774880816610&dpr=off
# <img alt="IBM technology solutions illustrated mural representing scalability, accessibility and speed" class="cmp-image__image" height="1536" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/bb4y_5x4?ts=1774880817824&amp;dpr=off" srcset="..." title="Illustration of digital tools and activities" width="1920"/>
# https://assets.ibm.com/is/image/ibm/bb4y_5x4?ts=1774880817824&dpr=off
# <img alt="Two people in a professional setting" class="cmp-image__image" height="1200" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/homepage-training-professional-4x3?ts=1774285682025&amp;dpr=off" srcset="..." title="Engineers Collaborating on Robotics Project in Lab Setting" width="1600"/>
# https://assets.ibm.com/is/image/ibm/homepage-training-professional-4x3?ts=1774285682025&dpr=off
# <img alt="Two people in a professional setting" class="cmp-image__image" height="1200" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/homepage-training-professional-4x3?ts=1774285682025&amp;dpr=off" srcset="..." title="Engineers Collaborating on Robotics Project in Lab Setting" width="1600"/>
# https://assets.ibm.com/is/image/ibm/homepage-training-professional-4x3?ts=1774285682025&dpr=off
# <img alt="A woman in a professional setting putting her skills to use" class="cmp-image__image" height="1200" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/homepage-training-foundational-4x3?ts=1774880822295&amp;dpr=off" srcset="..." title="Engineer operating robotic arm in modern workspace" width="1601"/>
# https://assets.ibm.com/is/image/ibm/homepage-training-foundational-4x3?ts=1774880822295&dpr=off
# <img alt="Student and instructor working on laptop" class="cmp-image__image" height="1200" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/homepage-training-students-4x3?ts=1774880823984&amp;dpr=off" srcset="..." title="Two Young Adults Collaborating on Laptop Project" width="1601"/>
# https://assets.ibm.com/is/image/ibm/homepage-training-students-4x3?ts=1774880823984&dpr=off
# <img alt="Illustration of an eye with connecting lines to data" class="cmp-image__image" height="2961" itemprop="contentUrl" loading="lazy" src="https://assets.ibm.com/is/image/ibm/watson-discovery_eye-connection_1x1_padding?ts=1774880826427&amp;dpr=off" srcset="..." width="2961"/>
# https://assets.ibm.com/is/image/ibm/watson-discovery_eye-connection_1x1_padding?ts=1774880826427&dpr=off

# %% [markdown]
# ### Scrape data from HTML tables

# %%
#The below url contains an html table with data about colors and color codes.
url = "https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/labs/datasets/HTMLColorCodes.html"

# %% [markdown]
# Before proceeding to scrape a web site, you need to examine the contents and the way data is organized on the website. Open the above url in your browser and check how many rows and columns there are in the color table.

# %%
# get the contents of the webpage in text format and store in a variable called data
data  = requests.get(url).text

# %%
soup = BeautifulSoup(data,"html.parser")

# %%
#find a html table in the web page
table = soup.find('table') # in html table is represented by the tag <table>

# %%
#Get all rows from the table
for row in table.find_all('tr'): # in html table row is represented by the tag <tr>
    # Get all columns in each row.
    cols = row.find_all('td') # in html a column is represented by the tag <td>
    color_name = cols[2].string # store the value in column 3 as color_name
    color_code = cols[3].string # store the value in column 4 as color_code
    print("{}--->{}".format(color_name,color_code))
# Out:
# Color Name--->None
# lightsalmon--->#FFA07A
# salmon--->#FA8072
# darksalmon--->#E9967A
# lightcoral--->#F08080
# coral--->#FF7F50
# tomato--->#FF6347
# orangered--->#FF4500
# gold--->#FFD700
# orange--->#FFA500
# darkorange--->#FF8C00
# lightyellow--->#FFFFE0
# lemonchiffon--->#FFFACD
# papayawhip--->#FFEFD5
# moccasin--->#FFE4B5
# peachpuff--->#FFDAB9
# palegoldenrod--->#EEE8AA
# khaki--->#F0E68C
# darkkhaki--->#BDB76B
# yellow--->#FFFF00
# lawngreen--->#7CFC00
# chartreuse--->#7FFF00
# limegreen--->#32CD32
# lime--->#00FF00
# forestgreen--->#228B22
# green--->#008000
# powderblue--->#B0E0E6
# lightblue--->#ADD8E6
# lightskyblue--->#87CEFA
# skyblue--->#87CEEB
# deepskyblue--->#00BFFF
# lightsteelblue--->#B0C4DE
# dodgerblue--->#1E90FF

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# |  Date (YYYY-MM-DD) |  Version | Changed By  |  Change Description |
# |---|---|---|---|
# | 2020-10-17  | 0.1  | Joseph Santarcangelo  Created initial version of the lab |

# %% [markdown]
#  Copyright &copy; 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license/).
